# %% [markdown]
# # Tokenization
#
# _Tokenization_ is the process of converting a body of text into individual _tokens_, e.g., words and punctuation characters. This is the first step for most Natural Language Processing (NLP) tasks, including preparing data for training an LLM. Let's see how it's done!

# %% [markdown]
# ## Some sample text

# %%
text = "This is a test! Or is this not a test? Test it to be sure. :)"
print(text)
print(f"This sample text has {len(text)} characters.")
# Out:
# This is a test! Or is this not a test? Test it to be sure. :)
# This sample text has 61 characters.

# %%
print( text.split() )
# Out:
# ['This', 'is', 'a', 'test!', 'Or', 'is', 'this', 'not', 'a', 'test?', 'Test', 'it', 'to', 'be', 'sure.', ':)']

# %%
import re

# %%
tokens = re.split( r'([.?!:()]|\s)', text)  #\s is white space... splits text into tokens   
tokens = [item for item in tokens if item.split()] #
tokens = sorted(list( set( tokens )))
print(tokens)
# Out:
# ['!', ')', '.', ':', '?', 'Or', 'Test', 'This', 'a', 'be', 'is', 'it', 'not', 'sure', 'test', 'this', 'to']

# %%
vocab = {token:index for index, token in enumerate(tokens)} #enumerate assigns a number to each term
print(vocab.items())
# Out:
# dict_items([('!', 0), ("'", 1), ("'Error,'", 2), ("'The", 3), ("'fine,", 4), ("'hands-off", 5), ("'heavy", 6), ('.', 7), ('1', 8), (':', 9), ('<|unk|>, <|endoftext|>', 10), ('?', 11), ('A', 12), ('All', 13), ('Almost', 14), ('Am', 15), ('And', 16), ('And,', 17), ('Anstruther', 18), ('Anstruther,”', 19), ('Anstruther—what', 20), ('Art', 21), ('At', 22), ('Briefly,', 23), ('But', 24), ('But,', 25), ('Calhoun', 26), ("Calhoun's", 27), ('Calhoun,', 28), ('Calhoun,”', 29), ('Calhoun—I', 30), ('Calhoun—it', 31), ('Can', 32), ('Carter——”', 33), ('Christian', 34), ('Coronet', 35), ('Dairy', 36), ('David', 37), ('David,', 38), ('David,”', 39), ('Death', 40), ('Did', 41), ("Didn't", 42), ('Do', 43), ("Don't", 44), ('Drawn', 45), ('Fancy', 46), ('Five', 47), ('For', 48), ('From', 49), ('Glad', 50), ('God', 51), ('God,', 52), ('Good-by,', 53), ('Halfway', 54), ('Hardy', 55), ("Hardy's", 56), ('Hardy,', 57), ('Hardy,”', 58), ('Hardy—may', 59), ('He', 60), ('Heaven', 61), ('Helen', 62), ('Helen,', 63), ('Helen,”', 64), ('Her', 65), ("Here's", 66), ('Hers', 67), ('His', 68), ('How', 69), ('I', 70), ("I'll", 71), ("I'm", 72), ("I've", 73), ('I,', 74), ('IF', 75), ('If', 76), ('In', 77), ('Is', 78), ("Isn't", 79), ('It', 80), ("It's", 81), ('Kit', 82), ('Kit,', 83), ('Kit,”', 84), ('Kitty', 85), ('Kit——”', 86), ('Let', 87), ('Like', 88), ('Long', 89), ("Lor'", 90), ('Lord,', 91), ("Maid'—a", 92), ('Man,', 93), ('Margaret', 94), ('Miss', 95), ('Most', 96), ('Mr', 97), ('My', 98), ('New', 99), ('No', 100), ('Now', 101), ('Now,', 102), ("O'Connor", 103), ("O'Connor,", 104), ("O'Connor—Mrs", 105), ('Of', 106), ('Oh,', 107), ('One', 108), ('Only', 109), ('Or', 110), ('Other', 111), ("Oughtn't", 112), ('Out', 113), ('Paris—but', 114), ('Perhaps', 115), ('Persian', 116), ('Poor', 117), ('Positively', 118), ('Presently,', 119), ('Probably', 120), ('Regular', 121), ('Right', 122), ('Shakespeare', 123), ('Shall', 124), ("Shan't", 125), ('She', 126), ("She'd", 127), ("She's", 128), ('Sign', 129), ('Simmons', 130), ('Simmons,', 131), ('Simmons;', 132), ('Some', 133), ('Still', 134), ('Success', 135), ('Suddenly', 136), ('Ten', 137), ('Thank', 138), ('That', 139), ('The', 140), ('Theater', 141), ('Then', 142), ('There', 143), ("There's", 144), ('There,', 145), ('They', 146), ("They're", 147), ("They've", 148), ('Those', 149), ('Try', 150), ('Two', 151), ('Unconsciously', 152), ('Wait', 153), ('We', 154), ('Well,', 155), ('What', 156), ('When', 157), ('Where', 158), ('Who', 159), ('Whom', 160), ('Why', 161), ('Why,', 162), ("Won't", 163), ('Would', 164), ('Yes', 165), ('Yes,', 166), ('You', 167), ("You'd", 168), ("You'll", 169), ('Your', 170), ('You—you', 171), ('a', 172), ('able', 173), ('about', 174), ('above', 175), ('abrupt', 176), ('absently,', 177), ('accompanied', 178), ('accustomed', 179), ('acknowledge', 180), ('acknowledgment', 181), ('acquaintanceship', 182), ('across', 183), ('act', 184), ('act,', 185), ('actor-manager', 186), ('actress', 187), ('actress,', 188), ('actresses', 189), ('act——', 190), ('addressed', 191), ('admired,', 192), ('admiringly', 193), ('adopted', 194), ('adorned', 195), ('advantage;', 196), ('affair', 197), ('affected', 198), ('afford', 199), ('after', 200), ('again', 201), ('against', 202), ('agitation', 203), ('ago', 204), ('ago,”', 205), ('ahead,', 206), ('air', 207), ('alive', 208), ('all', 209), ('all,', 210), ('all—the', 211), ('almost', 212), ('alone', 213), ('along', 214), ('already', 215), ('already,”', 216), ('also,', 217), ('always', 218), ('am', 219), ('amazed', 220), ('ambition', 221), ('ambition,', 222), ('amused,', 223), ('an', 224), ('and', 225), ('and,', 226), ('angry', 227), ('animal', 228), ('annoyed', 229), ('another', 230), ('answer', 231), ('answer;', 232), ('answered', 233), ('answered,', 234), ('anticipate', 235), ('anxiety', 236), ('anxiously,', 237), ('any', 238), ("anybody's", 239), ('anyhow', 240), ('apparently', 241), ('appeared', 242), ('applause', 243), ('approach', 244), ('approaching', 245) ...

# %%
vocab["a"]
# Out:
# 8

# %%
with open("ShortStory.txt", "r") as f:
    raw_text= f.read()

print(raw_text[:50])
# Out:
# IF you please, ma'am, dinner is served.”
#
# David Ha

# %%
tokens = re.split( r'([.?!:()]|\s)', raw_text)  #\s is white space... splits text into tokens   
tokens = [item for item in tokens if item.split()] 
tokens.extend(["<|unk|>", "<|endoftext|>"])
print( len(tokens))
# Out:
# 6936

# %%
tokens = sorted(list( set( tokens )))
print(len(tokens))
# Out:
# 1917

# %%
print(tokens[:25])
# Out:
# ['!', "'", "'Error,'", "'The", "'fine,", "'hands-off", "'heavy", '.', '1', ':', '<|endoftext|>', '<|unk|>', '?', 'A', 'All', 'Almost', 'Am', 'And', 'And,', 'Anstruther', 'Anstruther,”', 'Anstruther—what', 'Art', 'At', 'Briefly,']

# %%
vocab = {token: index for index, token in enumerate(tokens)}
vocab.items()
# Out:
# dict_items([('!', 0), ("'", 1), ("'Error,'", 2), ("'The", 3), ("'fine,", 4), ("'hands-off", 5), ("'heavy", 6), ('.', 7), ('1', 8), (':', 9), ('<|endoftext|>', 10), ('<|unk|>', 11), ('?', 12), ('A', 13), ('All', 14), ('Almost', 15), ('Am', 16), ('And', 17), ('And,', 18), ('Anstruther', 19), ('Anstruther,”', 20), ('Anstruther—what', 21), ('Art', 22), ('At', 23), ('Briefly,', 24), ('But', 25), ('But,', 26), ('Calhoun', 27), ("Calhoun's", 28), ('Calhoun,', 29), ('Calhoun,”', 30), ('Calhoun—I', 31), ('Calhoun—it', 32), ('Can', 33), ('Carter——”', 34), ('Christian', 35), ('Coronet', 36), ('Dairy', 37), ('David', 38), ('David,', 39), ('David,”', 40), ('Death', 41), ('Did', 42), ("Didn't", 43), ('Do', 44), ("Don't", 45), ('Drawn', 46), ('Fancy', 47), ('Five', 48), ('For', 49), ('From', 50), ('Glad', 51), ('God', 52), ('God,', 53), ('Good-by,', 54), ('Halfway', 55), ('Hardy', 56), ("Hardy's", 57), ('Hardy,', 58), ('Hardy,”', 59), ('Hardy—may', 60), ('He', 61), ('Heaven', 62), ('Helen', 63), ('Helen,', 64), ('Helen,”', 65), ('Her', 66), ("Here's", 67), ('Hers', 68), ('His', 69), ('How', 70), ('I', 71), ("I'll", 72), ("I'm", 73), ("I've", 74), ('I,', 75), ('IF', 76), ('If', 77), ('In', 78), ('Is', 79), ("Isn't", 80), ('It', 81), ("It's", 82), ('Kit', 83), ('Kit,', 84), ('Kit,”', 85), ('Kitty', 86), ('Kit——”', 87), ('Let', 88), ('Like', 89), ('Long', 90), ("Lor'", 91), ('Lord,', 92), ("Maid'—a", 93), ('Man,', 94), ('Margaret', 95), ('Miss', 96), ('Most', 97), ('Mr', 98), ('My', 99), ('New', 100), ('No', 101), ('Now', 102), ('Now,', 103), ("O'Connor", 104), ("O'Connor,", 105), ("O'Connor—Mrs", 106), ('Of', 107), ('Oh,', 108), ('One', 109), ('Only', 110), ('Or', 111), ('Other', 112), ("Oughtn't", 113), ('Out', 114), ('Paris—but', 115), ('Perhaps', 116), ('Persian', 117), ('Poor', 118), ('Positively', 119), ('Presently,', 120), ('Probably', 121), ('Regular', 122), ('Right', 123), ('Shakespeare', 124), ('Shall', 125), ("Shan't", 126), ('She', 127), ("She'd", 128), ("She's", 129), ('Sign', 130), ('Simmons', 131), ('Simmons,', 132), ('Simmons;', 133), ('Some', 134), ('Still', 135), ('Success', 136), ('Suddenly', 137), ('Ten', 138), ('Thank', 139), ('That', 140), ('The', 141), ('Theater', 142), ('Then', 143), ('There', 144), ("There's", 145), ('There,', 146), ('They', 147), ("They're", 148), ("They've", 149), ('Those', 150), ('Try', 151), ('Two', 152), ('Unconsciously', 153), ('Wait', 154), ('We', 155), ('Well,', 156), ('What', 157), ('When', 158), ('Where', 159), ('Who', 160), ('Whom', 161), ('Why', 162), ('Why,', 163), ("Won't", 164), ('Would', 165), ('Yes', 166), ('Yes,', 167), ('You', 168), ("You'd", 169), ("You'll", 170), ('Your', 171), ('You—you', 172), ('a', 173), ('able', 174), ('about', 175), ('above', 176), ('abrupt', 177), ('absently,', 178), ('accompanied', 179), ('accustomed', 180), ('acknowledge', 181), ('acknowledgment', 182), ('acquaintanceship', 183), ('across', 184), ('act', 185), ('act,', 186), ('actor-manager', 187), ('actress', 188), ('actress,', 189), ('actresses', 190), ('act——', 191), ('addressed', 192), ('admired,', 193), ('admiringly', 194), ('adopted', 195), ('adorned', 196), ('advantage;', 197), ('affair', 198), ('affected', 199), ('afford', 200), ('after', 201), ('again', 202), ('against', 203), ('agitation', 204), ('ago', 205), ('ago,”', 206), ('ahead,', 207), ('air', 208), ('alive', 209), ('all', 210), ('all,', 211), ('all—the', 212), ('almost', 213), ('alone', 214), ('along', 215), ('already', 216), ('already,”', 217), ('also,', 218), ('always', 219), ('am', 220), ('amazed', 221), ('ambition', 222), ('ambition,', 223), ('amused,', 224), ('an', 225), ('and', 226), ('and,', 227), ('angry', 228), ('animal', 229), ('annoyed', 230), ('another', 231), ('answer', 232), ('answer;', 233), ('answered', 234), ('answered,', 235), ('anticipate', 236), ('anxiety', 237), ('anxiously,', 238), ('any', 239), ("anybody's", 240), ('anyhow', 241), ('apparently', 242), ('appeared', 243), ('applause', 244), ('approach', 245), ('approachi ...

# %%
phrase= "He tried to laugh, but failed rather badly;"
print(phrase)
# Out:
# He tried to laugh, but failed rather badly;

# %%
phrase= re.split( r'([.?!:()]|\s)', phrase)
phrase= [item for item in phrase if item.split()]
print(phrase)
# Out:
# ['He', 'tried', 'to', 'laugh,', 'but', 'failed', 'rather', 'badly;']

# %%
ids= [vocab[token] for token in phrase]
print(ids)
# Out:
# [61, 1667, 1647, 977, 364, 652, 1297, 278]

# %%
reverse_vocab= {index:token for token,index in vocab.items()}
reverse_vocab.items()
# Out:
# dict_items([(0, '!'), (1, "'"), (2, "'Error,'"), (3, "'The"), (4, "'fine,"), (5, "'hands-off"), (6, "'heavy"), (7, '.'), (8, '1'), (9, ':'), (10, '<|endoftext|>'), (11, '<|unk|>'), (12, '?'), (13, 'A'), (14, 'All'), (15, 'Almost'), (16, 'Am'), (17, 'And'), (18, 'And,'), (19, 'Anstruther'), (20, 'Anstruther,”'), (21, 'Anstruther—what'), (22, 'Art'), (23, 'At'), (24, 'Briefly,'), (25, 'But'), (26, 'But,'), (27, 'Calhoun'), (28, "Calhoun's"), (29, 'Calhoun,'), (30, 'Calhoun,”'), (31, 'Calhoun—I'), (32, 'Calhoun—it'), (33, 'Can'), (34, 'Carter——”'), (35, 'Christian'), (36, 'Coronet'), (37, 'Dairy'), (38, 'David'), (39, 'David,'), (40, 'David,”'), (41, 'Death'), (42, 'Did'), (43, "Didn't"), (44, 'Do'), (45, "Don't"), (46, 'Drawn'), (47, 'Fancy'), (48, 'Five'), (49, 'For'), (50, 'From'), (51, 'Glad'), (52, 'God'), (53, 'God,'), (54, 'Good-by,'), (55, 'Halfway'), (56, 'Hardy'), (57, "Hardy's"), (58, 'Hardy,'), (59, 'Hardy,”'), (60, 'Hardy—may'), (61, 'He'), (62, 'Heaven'), (63, 'Helen'), (64, 'Helen,'), (65, 'Helen,”'), (66, 'Her'), (67, "Here's"), (68, 'Hers'), (69, 'His'), (70, 'How'), (71, 'I'), (72, "I'll"), (73, "I'm"), (74, "I've"), (75, 'I,'), (76, 'IF'), (77, 'If'), (78, 'In'), (79, 'Is'), (80, "Isn't"), (81, 'It'), (82, "It's"), (83, 'Kit'), (84, 'Kit,'), (85, 'Kit,”'), (86, 'Kitty'), (87, 'Kit——”'), (88, 'Let'), (89, 'Like'), (90, 'Long'), (91, "Lor'"), (92, 'Lord,'), (93, "Maid'—a"), (94, 'Man,'), (95, 'Margaret'), (96, 'Miss'), (97, 'Most'), (98, 'Mr'), (99, 'My'), (100, 'New'), (101, 'No'), (102, 'Now'), (103, 'Now,'), (104, "O'Connor"), (105, "O'Connor,"), (106, "O'Connor—Mrs"), (107, 'Of'), (108, 'Oh,'), (109, 'One'), (110, 'Only'), (111, 'Or'), (112, 'Other'), (113, "Oughtn't"), (114, 'Out'), (115, 'Paris—but'), (116, 'Perhaps'), (117, 'Persian'), (118, 'Poor'), (119, 'Positively'), (120, 'Presently,'), (121, 'Probably'), (122, 'Regular'), (123, 'Right'), (124, 'Shakespeare'), (125, 'Shall'), (126, "Shan't"), (127, 'She'), (128, "She'd"), (129, "She's"), (130, 'Sign'), (131, 'Simmons'), (132, 'Simmons,'), (133, 'Simmons;'), (134, 'Some'), (135, 'Still'), (136, 'Success'), (137, 'Suddenly'), (138, 'Ten'), (139, 'Thank'), (140, 'That'), (141, 'The'), (142, 'Theater'), (143, 'Then'), (144, 'There'), (145, "There's"), (146, 'There,'), (147, 'They'), (148, "They're"), (149, "They've"), (150, 'Those'), (151, 'Try'), (152, 'Two'), (153, 'Unconsciously'), (154, 'Wait'), (155, 'We'), (156, 'Well,'), (157, 'What'), (158, 'When'), (159, 'Where'), (160, 'Who'), (161, 'Whom'), (162, 'Why'), (163, 'Why,'), (164, "Won't"), (165, 'Would'), (166, 'Yes'), (167, 'Yes,'), (168, 'You'), (169, "You'd"), (170, "You'll"), (171, 'Your'), (172, 'You—you'), (173, 'a'), (174, 'able'), (175, 'about'), (176, 'above'), (177, 'abrupt'), (178, 'absently,'), (179, 'accompanied'), (180, 'accustomed'), (181, 'acknowledge'), (182, 'acknowledgment'), (183, 'acquaintanceship'), (184, 'across'), (185, 'act'), (186, 'act,'), (187, 'actor-manager'), (188, 'actress'), (189, 'actress,'), (190, 'actresses'), (191, 'act——'), (192, 'addressed'), (193, 'admired,'), (194, 'admiringly'), (195, 'adopted'), (196, 'adorned'), (197, 'advantage;'), (198, 'affair'), (199, 'affected'), (200, 'afford'), (201, 'after'), (202, 'again'), (203, 'against'), (204, 'agitation'), (205, 'ago'), (206, 'ago,”'), (207, 'ahead,'), (208, 'air'), (209, 'alive'), (210, 'all'), (211, 'all,'), (212, 'all—the'), (213, 'almost'), (214, 'alone'), (215, 'along'), (216, 'already'), (217, 'already,”'), (218, 'also,'), (219, 'always'), (220, 'am'), (221, 'amazed'), (222, 'ambition'), (223, 'ambition,'), (224, 'amused,'), (225, 'an'), (226, 'and'), (227, 'and,'), (228, 'angry'), (229, 'animal'), (230, 'annoyed'), (231, 'another'), (232, 'answer'), (233, 'answer;'), (234, 'answered'), (235, 'answered,'), (236, 'anticipate'), (237, 'anxiety'), (238, 'anxiously,'), (239, 'any'), (240, "anybody's"), (241, 'anyhow'), (242, 'apparently'), (243, 'appeared'), (244, 'applause'), (245, 'approach'), (246, 'appr ...

# %%
print(" ".join([ reverse_vocab[id] for id in ids]))
# Out:
# He tried to laugh, but failed rather badly;

# %%
class SimpleTokenizer:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {index:token for token, index in vocab.items()}

    def encode(self, text):
        tokens= re.split( r'([.?!:()]|\s)', text)
        tokens= [item if item in self.str_to_int else "<|unk|>" for item in tokens if item.split()]
        ids= [self.str_to_int[token] for token in tokens]
        return ids

    def decode(self, ids):
        text= " ".join([self.int_to_str[id] for id in ids])
        text= re.sub( r'\s+([.?!:())"\'^])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizer(vocab)

# %%
phrase= "He hesitated. For a full minute, he stood looking away from her; and then, with a slow, uncertain step, he went to the writing table by the window,"

# %%
ids= tokenizer.encode(phrase)
print(ids)
# Out:
# [61, 854, 7, 49, 173, 743, 1082, 827, 1524, 1021, 270, 740, 847, 226, 1608, 1770, 173, 1462, 1687, 1521, 827, 1737, 1647, 1601, 1800, 1563, 366, 1601, 11]

# %%
text= tokenizer.decode(ids)
print(text)
# Out:
# He hesitated. For a full minute, he stood looking away from her; and then, with a slow, uncertain step, he went to the writing table by the <|unk|>

# %%
different_phrase= "And all day long he had sat at the handsome table and looked out over the gray river at the masts piercing the mists"

# %%
ids= tokenizer.encode(different_phrase)
print(ids)

# %%
text= tokenizer.decode(ids)
print(text)

# %%
#End of Tokenizer Assignment

# %%
import tiktoken

# %%
tokenizer= tiktoken.get_encoding("gpt2")
